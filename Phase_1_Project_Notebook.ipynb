# %% [markdown]
# # Business Understanding

# %% [markdown]
# # Data understanding

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#importing all libraries

import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading bom movie gross details

bom_movie = pd.read_csv('/content/drive/MyDrive/bom.movie_gross.csv')
bom_movie.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
#Get the shape of the DataFrame
bom_movie.shape
# Out:
# (3387, 5)

# %%
#Get info on the DataFrame
bom_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
#Loading tmdb movies data set

tmdb_movies = pd.read_csv('/content/drive/MyDrive/tmdb.movies.csv')
tmdb_movies.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
#Get the shape of the DataFrame
tmdb_movies.shape
# Out:
# (26517, 10)

# %%
#Get info on the DataFrame
tmdb_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
#Loading tn.movie budgets dataset
tn_movie_budgets = pd.read_csv('/content/drive/MyDrive/tn.movie_budgets.csv')
tn_movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
#Get the shape of the DataFrame
tn_movie_budgets.shape
# Out:
# (5782, 6)

# %%
#Get info on the Data frame
tn_movie_budgets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
#Show the summary stastistics of bom movie
bom_movie.describe()
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %% [markdown]
# Since foreign gross is not included because it was an object, we convert it to numeric

# %%
bom_movie['foreign_gross'] = pd.to_numeric(bom_movie['foreign_gross'],errors='coerce')

# %%
bom_movie.describe()
# Out:
#        domestic_gross  foreign_gross         year
# count    3.359000e+03   2.032000e+03  3387.000000
# mean     2.874585e+07   7.505704e+07  2013.958075
# std      6.698250e+07   1.375294e+08     2.478141
# min      1.000000e+02   6.000000e+02  2010.000000
# 25%      1.200000e+05   3.775000e+06  2012.000000
# 50%      1.400000e+06   1.890000e+07  2014.000000
# 75%      2.790000e+07   7.505000e+07  2016.000000
# max      9.367000e+08   9.605000e+08  2018.000000

# %%
tn_movie_budgets.describe()
# Out:
#                 id
# count  5782.000000
# mean     50.372363
# std      28.821076
# min       1.000000
# 25%      25.000000
# 50%      50.000000
# 75%      75.000000
# max     100.000000

# %% [markdown]
# Since production budget, domestic gross and worldwide gross are all in object datatype, we convert them to numeric

# %%
#Converting the objects to strings
tn_movie_budgets['production_budget']= tn_movie_budgets['production_budget'].str.replace("$",'')
tn_movie_budgets['domestic_gross']= tn_movie_budgets['domestic_gross'].str.replace("$",'')
tn_movie_budgets['worldwide_gross']= tn_movie_budgets['worldwide_gross'].str.replace("$",'')

tn_movie_budgets['production_budget']=tn_movie_budgets['production_budget'].str.replace(',','')
tn_movie_budgets['domestic_gross']=tn_movie_budgets['domestic_gross'].str.replace(',','')
tn_movie_budgets['worldwide_gross']=tn_movie_budgets['worldwide_gross'].str.replace(',','')

tn_movie_budgets.head()
# Out:
# <ipython-input-65-124fa904bdf3>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   tn_movie_budgets['production_budget']= tn_movie_budgets['production_budget'].str.replace("$",'')
# <ipython-input-65-124fa904bdf3>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   tn_movie_budgets['domestic_gross']= tn_movie_budgets['domestic_gross'].str.replace("$",'')
# <ipython-input-65-124fa904bdf3>:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
#Convert the strings to integers
tn_movie_budgets['production_budget']=tn_movie_budgets['production_budget'].astype(int)
tn_movie_budgets['domestic_gross']=tn_movie_budgets['domestic_gross'].astype(int)
tn_movie_budgets['worldwide_gross']=tn_movie_budgets['worldwide_gross'].astype(np.int64)

tn_movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross
# 0          425000000       760507625       2776345279
# 1          410600000       241063875       1045663875
# 2          350000000        42762350        149762350
# 3          330600000       459005868       1403013963
# 4          317000000       620181382       1316721747

# %%
tn_movie_budgets.describe()
# Out:
#                 id  production_budget  domestic_gross  worldwide_gross
# count  5782.000000       5.782000e+03    5.782000e+03     5.782000e+03
# mean     50.372363       3.158776e+07    4.187333e+07     9.148746e+07
# std      28.821076       4.181208e+07    6.824060e+07     1.747200e+08
# min       1.000000       1.100000e+03    0.000000e+00     0.000000e+00
# 25%      25.000000       5.000000e+06    1.429534e+06     4.125415e+06
# 50%      50.000000       1.700000e+07    1.722594e+07     2.798445e+07
# 75%      75.000000       4.000000e+07    5.234866e+07     9.764584e+07
# max     100.000000       4.250000e+08    9.366622e+08     2.776345e+09

# %% [markdown]
# Now we are able to see the summary statistics for production budget, domestic_gross and worldwide_gross

# %% [markdown]
# Let's now connect to the database and view its contents

# %%
#Establishing connection to the sql database and checking the available tables
conn = sqlite3.connect('/content/drive/MyDrive/im.db')
pd.read_sql("""
SELECT name
FROM sqlite_master
WHERE type = 'table';
""",conn)
# Out:
#             name
# 0   movie_basics
# 1      directors
# 2      known_for
# 3     movie_akas
# 4  movie_ratings
# 5        persons
# 6     principals
# 7        writers

# %%
#connecting to the sql database with imdb ratings and reading the first 5 rows
im_movie_ratings = pd.read_sql("""
                  SELECT*
                  FROM movie_ratings;
                  """,conn)
im_movie_ratings.head()
# Out:
#      movie_id  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
#connecting to the sql database with imdbbasics and reading the first 5 rows
im_movie_basics = pd.read_sql("""
                  SELECT*
                  FROM movie_basics;
                  """,conn)
im_movie_basics.head()
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %% [markdown]
# # Data Preparation

# %% [markdown]
# # Data Analysis

# %% [markdown]
# # Visualization
